# %% [markdown]
# # Project 3
# The students need to create a program that makes use of a loop to make the car drive.
#
# Their program needs to:
# - Use any type of loop to move the car with the use of more interesting movement.
# - Students are free to do what they want so long as they satisfy the loop + movement condition.
# - An example would be, making the car travel forward in a zigzag, or travel in a circular motion.
