# %% [markdown]
# # Project 4
# The students need to create an improved morse code program.
#
# Their program needs to:
# - take morse code inputs with a list. Example for SOS [0, 0, 0, 1, 1, 1, 0, 0, 0] and then use a loop to go through the list and trigger the buzzer
